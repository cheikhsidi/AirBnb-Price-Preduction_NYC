# %%
# from azureml.core import Workspace
import pandas as pd
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy.orm import sessionmaker
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import os

# %% [markdown]
# # Loading Data

# %%
# Loading the Dataset
df1 = pd.read_csv('airbnb_nyc.csv')
df1.head()
# Out:
#    Unnamed: 0      id  host_id host_since  host_response_time  \
# 0           0  918239  4930847   2/1/2013  a few days or more
# 1           1  918426  4932354   2/1/2013      within an hour
# 2           2  919491  4938247   2/2/2013        within a day
# 3           3  919830  1895793  3/10/2012      within an hour
# 4           4  919955   794794   7/8/2011        within a day
#
#   host_response_rate  host_acceptance_rate Superhost host_neighbourhood  \
# 0                20%                     0        No       Williamsburg
# 1               100%                     0       Yes   Prospect Heights
# 2               100%                     0        No         Park Slope
# 3               100%                     0       Yes            Chelsea
# 4                67%                     0        No    Upper East Side
#
#    host_listings_count  ...  minimum_nights maximum_nights availability_365  \
# 0                    1  ...               1             90               64
# 1                    4  ...               3             14              134
# 2                    1  ...               2            180                0
# 3                    1  ...               2              7              167
# 4                    1  ...              14           1124              354
#
#   calendar_last_scraped number_of_reviews Review_Rating  \
# 0             12/6/2019               114            95
# 1             12/6/2019                80            93
# 2             12/5/2019               175            93
# 3             12/6/2019               176            96
# 4             12/6/2019                11            96
#
#   review_scores_cleanliness review_scores_value  instant_bookable  \
# 0                         9                  10                 f
# 1                         9                  10                 f
# 2                         9                   9                 f
# 3                        10                  10                 t
# 4                         9                   9                 f
#
#    Review Rating
# 0   4th Quartile
# 1   4th Quartile
# 2   4th Quartile
# 3   4th Quartile
# 4   4th Quartile
#
# [5 rows x 45 columns]

# %%
# Dumping all irrelevant columns
df = df1.drop(['id','neighbourhood', 'Review Rating','host_since', 'host_response_time','amenities',
               'street', 'host_verifications','calendar_last_scraped','host_identity_verified',  'host_has_profile_pic', 
               'neighbourhood_cleansed',  'instant_bookable','host_acceptance_rate', 'host_id', 'host_listings_count', 
               'host_total_listings_count', 'minimum_nights', 'maximum_nights', 'property_type', 'host_neighbourhood', 'Unnamed: 0'], axis = 1)

# %%
# Checking for nulls 
df.isnull().sum()
# Out:
# host_response_rate           0
# Superhost                    0
# Borough                      0
# latitude                     0
# longitude                    0
# Room_Type                    0
# accommodates                 0
# bathrooms                    0
# bedrooms                     0
# beds                         0
# bed_type                     0
# Price                        0
# weekly_price                 0
# monthly_price                0
# security_deposit             0
# cleaning_fee                 0
# guests_included              0
# extra_people                 0
# availability_365             0
# number_of_reviews            0
# Review_Rating                0
# review_scores_cleanliness    0
# review_scores_value          0
# dtype: int64

# %%
# inspeting the all the columns datatypes
df.head().T
# Out:
#                                       0             1             2  \
# host_response_rate                  20%          100%          100%
# Superhost                            No           Yes            No
# Borough                        Brooklyn      Brooklyn      Brooklyn
# latitude                        40.7016       40.6785       40.6767
# longitude                      -73.9435      -73.9701      -73.9792
# Room_Type                  Private room  Private room  Private room
# accommodates                          1             2             4
# bathrooms                             1             1             1
# bedrooms                              1             1             1
# beds                                  0             1             2
# bed_type                       Real Bed      Real Bed      Real Bed
# Price                                60            70            70
# weekly_price                   $500.00       $450.00       $600.00
# monthly_price                $1,800.00              0    $2,000.00
# security_deposit                      0           200             0
# cleaning_fee                         25            20            30
# guests_included                       1             1             2
# extra_people                    $20.00        $10.00        $30.00
# availability_365                     64           134             0
# number_of_reviews                   114            80           175
# Review_Rating                        95            93            93
# review_scores_cleanliness             9             9             9
# review_scores_value                  10            10             9
#
#                                       3                4
# host_response_rate                 100%              67%
# Superhost                           Yes               No
# Borough                       Manhattan        Manhattan
# latitude                         40.746           40.764
# longitude                      -73.9991         -73.9639
# Room_Type                  Private room  Entire home/apt
# accommodates                          2                3
# bathrooms                             1                1
# bedrooms                              1                1
# beds                                  1                1
# bed_type                       Real Bed         Real Bed
# Price                               125              220
# weekly_price                          0       $1,950.00
# monthly_price                         0       $6,300.00
# security_deposit                      0             1000
# cleaning_fee                          0              125
# guests_included                       1                2
# extra_people                    $50.00           $50.00
# availability_365                    167              354
# number_of_reviews                   176               11
# Review_Rating                        96               96
# review_scores_cleanliness            10                9
# review_scores_value                  10                9

# %%
# Transforming and casting to numerical data type
df['host_response_rate'] = df['host_response_rate'].str.replace('%', '').astype(int)
df['extra_people'] = df['extra_people'].str.replace('$', '').str.replace(',', '').str.strip().astype(float)
df['weekly_price'] = df['weekly_price'].str.replace('$', '').str.replace(',', '').str.strip().astype(float)
df['monthly_price'] = df['monthly_price'].str.replace('$', '').str.replace(',', '').str.strip().astype(float)
df['bathrooms'] = df['bathrooms'].astype(float)
df['bedrooms'] = df['bedrooms'].astype(float)

# %%
# # Creating Location column from lat-long
# cols =['latitude', 'longitude']
# df['location'] = df[cols].apply(lambda row: ', '.join(row.values.astype(str)), axis=1)
# df['location'] =  df['location'].apply(lambda row: tuple(map(float, row.split(', '))))

# %%
# checking visually the columns data type
df.head().T
# Out:
#                                       0             1             2  \
# host_response_rate                   20           100           100
# Superhost                            No           Yes            No
# Borough                        Brooklyn      Brooklyn      Brooklyn
# latitude                        40.7016       40.6785       40.6767
# longitude                      -73.9435      -73.9701      -73.9792
# Room_Type                  Private room  Private room  Private room
# accommodates                          1             2             4
# bathrooms                             1             1             1
# bedrooms                              1             1             1
# beds                                  0             1             2
# bed_type                       Real Bed      Real Bed      Real Bed
# Price                                60            70            70
# weekly_price                        500           450           600
# monthly_price                      1800             0          2000
# security_deposit                      0           200             0
# cleaning_fee                         25            20            30
# guests_included                       1             1             2
# extra_people                         20            10            30
# availability_365                     64           134             0
# number_of_reviews                   114            80           175
# Review_Rating                        95            93            93
# review_scores_cleanliness             9             9             9
# review_scores_value                  10            10             9
#
#                                       3                4
# host_response_rate                  100               67
# Superhost                           Yes               No
# Borough                       Manhattan        Manhattan
# latitude                         40.746           40.764
# longitude                      -73.9991         -73.9639
# Room_Type                  Private room  Entire home/apt
# accommodates                          2                3
# bathrooms                             1                1
# bedrooms                              1                1
# beds                                  1                1
# bed_type                       Real Bed         Real Bed
# Price                               125              220
# weekly_price                          0             1950
# monthly_price                         0             6300
# security_deposit                      0             1000
# cleaning_fee                          0              125
# guests_included                       1                2
# extra_people                         50               50
# availability_365                    167              354
# number_of_reviews                   176               11
# Review_Rating                        96               96
# review_scores_cleanliness            10                9
# review_scores_value                  10                9

# %% [markdown]
# Data Exploration

# %%
# checking the columns data type
df.dtypes
# Out:
# host_response_rate             int32
# Superhost                     object
# Borough                       object
# latitude                     float64
# longitude                    float64
# Room_Type                     object
# accommodates                   int64
# bathrooms                    float64
# bedrooms                     float64
# beds                           int64
# bed_type                      object
# Price                        float64
# weekly_price                 float64
# monthly_price                float64
# security_deposit               int64
# cleaning_fee                   int64
# guests_included                int64
# extra_people                 float64
# availability_365               int64
# number_of_reviews              int64
# Review_Rating                  int64
# review_scores_cleanliness      int64
# review_scores_value            int64
# dtype: object

# %%
# Removinf price outliers
df = df[df['Price'] <400]
len(df)
# Out:
# 48568

# %%
# Plotting the distribution of the price
ax = sb.distplot(df['Price'], axlabel='Listing Price')

# %%
# Price vs location
plt.figure(figsize=(40,6))
plt.scatter(df['longitude'], df['Price'])

# %%
# Calculating the Distance from Time Square 
import geopy.distance

cols =['latitude', 'longitude']
df['location'] = df[cols].apply(lambda row: ', '.join(row.values.astype(str)), axis=1)
df['location'] =  df['location'].apply(lambda row: tuple(map(float, row.split(', '))))

# Time Square Location
coords = (40.758896, -73.985130)
df['distance'] =  df['location'].apply(lambda row: geopy.distance.vincenty(coords, row).miles)
# print geopy.distance.vincenty(coords_1, coords_2).km
df['distance']
# Out:
# c:\users\cheikh_moctar\documents\ucf_bootcamp\ripos_git\class_repo\env\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
#   # Remove the CWD from sys.path while we load stuff.
# 0        4.518910
# 1        5.602132
# 2        5.683554
# 3        1.148927
# 4        1.170857
#            ...
# 50594    6.538442
# 50595    2.457599
# 50596    1.888921
# 50597    1.432552
# 50598    5.804301
# Name: distance, Length: 48568, dtype: float64

# %%
# Creating coorelation between all features
corr = df.corr()
corr
# Out:
#                            host_response_rate  latitude  longitude  \
# host_response_rate                   1.000000 -0.016446   0.108878
# latitude                            -0.016446  1.000000   0.081726
# longitude                            0.108878  0.081726   1.000000
# accommodates                         0.143451 -0.047781   0.021202
# bathrooms                            0.062316 -0.077362   0.036392
# bedrooms                             0.075463 -0.082149   0.066045
# beds                                 0.128480 -0.059592   0.035939
# Price                                0.049112  0.073582  -0.300487
# weekly_price                        -0.063643 -0.003112  -0.076594
# monthly_price                        0.012111  0.010841  -0.063068
# security_deposit                     0.057280  0.020213  -0.084781
# cleaning_fee                         0.217384  0.021597  -0.169428
# guests_included                      0.150527 -0.063224   0.051897
# extra_people                         0.128986 -0.002079   0.024546
# availability_365                     0.457889 -0.008316   0.091408
# number_of_reviews                    0.291689 -0.014460   0.055670
# Review_Rating                        0.221325 -0.033557   0.038622
# review_scores_cleanliness            0.236799 -0.033439   0.046144
# review_scores_value                  0.217586 -0.035886   0.044873
# distance                             0.095864 -0.414800   0.548592
#
#                            accommodates  bathrooms  bedrooms      beds  \
# host_response_rate             0.143451   0.062316  0.075463  0.128480
# latitude                      -0.047781  -0.077362 -0.082149 -0.059592
# longitude                      0.021202   0.036392  0.066045  0.035939
# accommodates                   1.000000   0.211702  0.605421  0.732416
# bathrooms                      0.211702   1.000000  0.284194  0.243485
# bedrooms                       0.605421   0.284194  1.000000  0.595385
# beds                           0.732416   0.243485  0.595385  1.000000
# Price                          0.506038   0.083103  0.306098  0.351525
# weekly_price                   0.065975   0.019751  0.064941  0.057692
# monthly_price                  0.073015   0.008365  0.061234  0.063937
# security_deposit               0.129372   0.029395  0.081553  0.098347
# cleaning_fee                   0.393048   0.092781  0.251460  0.298870
# guests_included                0.560641   0.118251  0.395785  0.465984
# extra_people                   0.097604   0.019589  0.077771  0.095997
# availability_365               0.127140   0.094527  0.063093  0.132556
# number_of_reviews              0.096231  -0.022754  0.033188  0.076780
# Review_Rating                  0.070356  -0.037086  0.017655  0.053547
# review_scores_cleanliness      0.078527  -0.038931  0.020933  0.059543
# review_scores_value            0.067415  -0.035117  0.018793  0.052005
# distance                       0.055178   0.064833  0.122461  0.088439
#
#                               Price  weekly_price  monthly_price  \
# host_response_rate         0.049112     -0.063643       0.012111
# latitude                   0.073582     -0.003112       0.010841
# longitude                 -0.300487     -0.076594      -0.063068
# accommodates               0.506038      0.065975       0.073015
# bathrooms                  0.083103      0.019751       0.008365
# bedrooms                   0.306098      0.064941       0.061234
# beds                       0.351525      0.057692       0.063937
# Price                      1.000000      0.135550       0.109931
# weekly_price               0.135550      1.000000       0.614312
# monthly_price              0.109931      0.614312       1.000000
# security_deposit           0.202200      0.093857       0.146669
# cleaning_fee               0.469421      0.087457       0.135147
# guests_included            0.307392      0.079700       0.077555
# extra_people               0.064427      0.073328       0.071760
# availability_365           0.066681     -0.003849       0.074489
# number_of_reviews         -0.037205      0.114679       0.143245
# Review_Rating             -0.036951      0.062220       0.076990
# review_scores_cleanliness -0.028091      0.058979       0.076350
# review_scores_value       -0.051210      0.058624       0.071025
# distance                  -0.364724     -0.056300      -0.063157
#
#                            security_deposit  cleaning_fee  guests_included  \
# host_response_rate                 0.057280      0.217384         0.150527
# latitude                           0.020213      0.021597        -0.063224
# longitude                         -0.084781     -0.169428         0.051897
# accommodates                       0.129372      0.393048         0.560641
# bathrooms                          0.029395      0.092781         0.118251
# bedrooms                           0.081553      0.251460         0.395785
# beds                               0.098347      0.298870         0.465984
# Price                              0.202200      0.469421         0.307392
# weekly_price                       0.093857      0.087457         0.079700
# monthly_price                      0.146669      0.135147         0.077555
# security_deposit                   1.000000      0.359705         0.107354
# cleaning_fee                       0.359705      1.000000         0.289844
# guests_included                    0.107354      0.289844         1.000000
# extra_people                       0.114673      0.145316         0.304642
# availability_365                   0.097844      0.203029         0.105531
# number_of_reviews                 -0.019964      0.001752         0.136611
# Review_Rating                     -0.000236      0.047123         0.119193
# review_scores_cleanliness          0.004974      0.056019         0.126631
# review_scores_value               -0.007848      0.034726         0.117594
# distance                          -0.092018     -0.178317         0.091005
#
#                            extra_people  availability_365  number_of_reviews  \
# host_response_rate             0.128986          0.457889           0.291689
# latitude                      -0.002079         -0.008316          -0.014460
# longitude                      0.024546          0.091408           0.055670
# accommodates                   0.097604          0.127140           0.096231
# bathrooms                      0.019589          0.094527          -0.022754
# bedrooms                       0.077771          0.063093           0.033188
# beds                           0.095997          0.132556           0.076780
# Price                          0.064427          0.066681          -0.037205
# weekly_price                   0.073328         -0.003849           0.114679
# monthly_price                  0.071760          0.074489           0.143245
# security_deposit               0.114673          0.097844          -0.019964
# cleaning_fee                   0.145316          0.203029           0.001752
# guests_included                0.304642          0.105531           0.136611
# extra_people                   1.000000          0.085920           0.123933
# availability_365               0.085920          1.000000           0.123783
# number_of_reviews              0.123933          0.123783           1.000000
# Review_Rating                  0.140392          0.020780           0.276530
# review_scores_cleanliness      0.145115          0.036830           0.285202
# review_scores_value            0.137205          0.014560           0.279540
# distance                       0.022807          0.087854           0.057487
#
#                            Review_Rating  review_scores_cleanliness  \
# host_response_rate              0.221325                   0.236799
# latitude                       -0.033557                  -0.033439
# longitude                       0.038622                   0.046144
# accommodates                    0.070356                   0.078527
# bathrooms                      -0.037086                  -0.038931
# bedrooms                        0.017655                   0.020933
# beds                            0.053547                   0.059543
# Price                          -0.036951                  -0.028091
# weekly_price                    0.062220                   0.058979
# monthly_price                   0.076990                   0.076350
# security_deposit               -0.000236                   0.004974
# cleaning_fee                    0.047123                   0.056019
# guests_included                 0.119193                   0.126631
# extra_people                    0.140392                   0.145115
# availability_365                0.020780                   0.036830
# number_of_reviews               0.276530                   0.285202
# Review_Rating                   1.000000                   0.984024
# review_scores_cleanliness       0.984024                   1.000000
# review_scores_value             0.987426                   0.977660
# distance                        0.065749                   0.073679
#
#                            review_scores_value  distance
# host_response_rate                    0.217586  0.095864
# latitude                             -0.035886 -0.414800
# longitude                             0.044873  0.548592
# accommodates                          0.067415  0.055178
# bathrooms                            -0.035117  0.064833
# bedrooms                              0.018793  0.122461
# beds                                  0.052005  0.088439
# Price                                -0.051210 -0.364724
# weekly_price                          0.058624 -0.056300
# monthly_price                         0.071025 -0.063157
# security_deposit                     -0.007848 -0.092018
# cleaning_fee                          0.034726 -0.178317
# guests_included                       0.117594  0.091005
# extra_people                          0.137205  0.022807
# availability_365                      0.014560  0.087854
# number_of_reviews                     0.279540  0.057487
# Review_Rating                         0.987426  0.065749
# review_scores_cleanliness             0.977660  0.073679
# review_scores_value                   1.000000  0.075540
# distance                              0.075540  1.000000

# %%
plt.figure(figsize=(15, 15))
corr = df.corr()
sb.heatmap(corr, annot=True, cmap = 'viridis_r')
plt.title('Correlation HeatMap')
# Out:
# Text(0.5, 1, 'Correlation HeatMap')

# %%
# Price vs Distance

plt.figure(figsize=(15, 5))
sb.regplot(data = df, x = "Price", y = 'distance', x_jitter = 0.1, 
            scatter_kws = {'alpha': 0.1})
plt.title('Price vs distance')
# Out:
# Text(0.5, 1.0, 'Price vs distance')

# %% [markdown]
# # Borough Exploratory and Analysis

# %%
Manhattan = df[df['Borough'] == 'Manhattan']
Brooklyn= df[df['Borough'] == 'Brooklyn']
Bronx = df[df['Borough'] == 'Bronx']
Queens = df[df['Borough'] == 'Queens']
StatenIsland = df[df['Borough'] == 'Staten Island']

# %%
Queens
# Out:
#        host_response_rate Superhost Borough  latitude  longitude  \
# 16                    100        No  Queens  40.70715  -73.81468
# 24                      0        No  Queens  40.75444  -73.83057
# 49                    100       Yes  Queens  40.70990  -73.91509
# 59                    100        No  Queens  40.76356  -73.88850
# 73                    100        No  Queens  40.75751  -73.91678
# ...                   ...       ...     ...       ...        ...
# 50496                  70        No  Queens  40.76014  -73.81146
# 50516                   0        No  Queens  40.76488  -73.92970
# 50564                 100       Yes  Queens  40.75088  -73.81029
# 50565                 100       Yes  Queens  40.75250  -73.81126
# 50570                   0        No  Queens  40.75374  -73.89240
#
#              Room_Type  accommodates  bathrooms  bedrooms  beds  ...  \
# 16     Entire home/apt             2        1.0       1.0     1  ...
# 24        Private room             2        1.0       1.0     1  ...
# 49     Entire home/apt             2        1.0       1.0     1  ...
# 59     Entire home/apt             4        1.0       1.0     1  ...
# 73     Entire home/apt             2        1.0       1.0     1  ...
# ...                ...           ...        ...       ...   ...  ...
# 50496     Private room             2        1.0       1.0     1  ...
# 50516  Entire home/apt             2        1.0       1.0     1  ...
# 50564     Private room             1        1.5       1.0     1  ...
# 50565  Entire home/apt             3        1.0       0.0     2  ...
# 50570     Private room             2        1.0       1.0     1  ...
#
#       cleaning_fee  guests_included  extra_people  availability_365  \
# 16              54                1          15.0               207
# 24              13                1          15.0                 0
# 49              25                2         100.0               311
# 59              55                2          15.0                 1
# 73              60                1          10.0               318
# ...            ...              ...           ...               ...
# 50496           10                1          20.0               353
# 50516          100                2          25.0               126
# 50564            0                1           0.0                 0
# 50565            0                2          10.0               312
# 50570           20                1           0.0                91
#
#        number_of_reviews  Review_Rating  review_scores_cleanliness  \
# 16                    88             93                          9
# 24                    75             94                         10
# 49                    80             95                         10
# 59                   165             90                          9
# 73                   292             88                          9
# ...                  ...            ...                        ...
# 50496                 43             92                          9
# 50516                  0              0                          0
# 50564                128             97                         10
# 50565                337             94                          9
# 50570                  0              0                          0
#
#        review_scores_value                         location  distance
# 16                       9   (40.70715, -73.81468000000001)  9.633027
# 24                       9            (40.75444, -73.83057)  8.115739
# 49                      10             (40.7099, -73.91509)  4.994522
# 59                       9             (40.76356, -73.8885)  5.080128
# 73                       9  (40.757509999999996, -73.91678)  3.587583
# ...                    ...                              ...       ...
# 50496                    9            (40.76014, -73.81146)  9.112648
# 50516                    0             (40.76488, -73.9297)  2.937405
# 50564                   10   (40.75088, -73.81029000000001)  9.190927
# 50565                   10             (40.7525, -73.81126)  9.133928
# 50570                    0             (40.75374, -73.8924)  4.878649
#
# [6129 rows x 25 columns]

# %%
# Price vs Distance Manahattan

plt.figure(figsize=(15, 5))
sb.regplot(data = Manhattan, x = "Price", y = 'distance', x_jitter = 0.1, 
            scatter_kws = {'alpha': 0.1})
plt.title('Price vs distance')
# Out:
# Text(0.5, 1.0, 'Price vs distance')

# %%
# Price vs Distance Bronx

plt.figure(figsize=(15, 5))
sb.regplot(data = Bronx, x = "Price", y = 'distance', x_jitter = 0.1, 
            scatter_kws = {'alpha': 0.1})
plt.title('Price vs distance')
# Out:
# Text(0.5, 1.0, 'Price vs distance')

# %%
# Price vs Distance Queens

plt.figure(figsize=(15, 5))
sb.regplot(data = Queens, x = "Price", y = 'distance', x_jitter = 0.1, 
            scatter_kws = {'alpha': 0.1})
plt.title('Price vs distance')
# Out:
# Text(0.5, 1.0, 'Price vs distance')

# %%
# Price vs Distance Brooklyn

plt.figure(figsize=(15, 5))
sb.regplot(data = Brooklyn, x = "Price", y = 'distance', x_jitter = 0.1, 
            scatter_kws = {'alpha': 0.1})
plt.title('Price vs distance')
# Out:
# Text(0.5, 1.0, 'Price vs distance')

# %%
# Price vs Distance Staten Island

plt.figure(figsize=(15, 5))
sb.regplot(data = StatenIsland, x = "Price", y = 'distance', x_jitter = 0.1, 
            scatter_kws = {'alpha': 0.1})
plt.title('Price vs distance')
# Out:
# Text(0.5, 1.0, 'Price vs distance')

# %% [markdown]
# # Room Type Exploratory and Analysis

# %%
EntireRoom = df[df['Room_Type']=='Entire home/apt']
PrivateRoom = df[df['Room_Type']=='Private room']
SharedRoom = df[df['Room_Type'] == 'Shared room']
HotelRoom = df[df['Room_Type'] == 'Hotel room']

# %%
# Price vs Distance Shared Room

plt.figure(figsize=(15, 5))
sb.regplot(data = SharedRoom, x = "Price", y = 'distance', x_jitter = 0.1, 
            scatter_kws = {'alpha': 0.1})
plt.title('Price vs distance')
# Out:
# Text(0.5, 1.0, 'Price vs distance')

# %%
# Price vs Distance Private Room

plt.figure(figsize=(15, 5))
sb.regplot(data = PrivateRoom, x = "Price", y = 'distance', x_jitter = 0.1, 
            scatter_kws = {'alpha': 0.1})
plt.title('Price vs distance')
# Out:
# Text(0.5, 1.0, 'Price vs distance')

# %%
# Price vs Distance Entire Home

plt.figure(figsize=(15, 5))
sb.regplot(data = EntireRoom, x = "Price", y = 'distance', x_jitter = 0.1, 
            scatter_kws = {'alpha': 0.1})
plt.title('Price vs distance')
# Out:
# Text(0.5, 1.0, 'Price vs distance')

# %%
# Price vs Distance HotelRoom

plt.figure(figsize=(15, 5))
sb.regplot(data = HotelRoom, x = "Price", y = 'distance', x_jitter = 0.1, 
            scatter_kws = {'alpha': 0.1})
plt.title('Price vs distance')
# Out:
# Text(0.5, 1.0, 'Price vs distance')

# %%
# sb.pairplot(Manhattan, hue='Price', size=2.5);

# %% [markdown]
# # Encoding Categorical fields

# %%
# Column list by data type
g = df.columns.to_series().groupby(df.dtypes).groups
g
# Out:
# {dtype('int32'): Index(['host_response_rate'], dtype='object'),
#  dtype('int64'): Index(['accommodates', 'beds', 'security_deposit', 'cleaning_fee',
#         'guests_included', 'availability_365', 'number_of_reviews',
#         'Review_Rating', 'review_scores_cleanliness', 'review_scores_value'],
#        dtype='object'),
#  dtype('float64'): Index(['latitude', 'longitude', 'bathrooms', 'bedrooms', 'Price',
#         'weekly_price', 'monthly_price', 'extra_people', 'distance'],
#        dtype='object'),
#  dtype('O'): Index(['Superhost', 'Borough', 'Room_Type', 'bed_type', 'location'], dtype='object')}

# %%
# Assign X (data) and y (target)
X = df.drop(['Price', 'location', 'Superhost', 'bed_type', 'Room_Type', 'Borough'], axis=1)

y = df ["Price"]
print(X.shape, y.shape)
# Out:
# (48568, 19) (48568,)

# %%
# cat_cols = ['Superhost', 'Borough',
#         'Room_type', 'bed_type']

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='sag')
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='sag', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(classifier, X, y, cv=5, scoring='accuracy').mean()
# Out:
# c:\users\cheikh_moctar\documents\ucf_bootcamp\ripos_git\class_repo\env\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)

# %%
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.compose import make_column_transformer
# from sklearn.pipeline import make_pipeline

# # x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
# column_tranf = make_column_transformer((OneHotEncoder(), cat_cols), remainder='passthrough')

# column_tranf.fit_transform(x_train)

# %%
# pipe = make_pipeline(column_tranf, classifier)

# %%
# from sklearn.model_selection import cross_val_score
# cross_val_score(pipe, x_train, y_train, cv=5, scoring='accuracy').mean()
# Out:
# c:\users\cheikh_moctar\documents\ucf_bootcamp\ripos_git\class_repo\env\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# c:\users\cheikh_moctar\documents\ucf_bootcamp\ripos_git\class_repo\env\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: A given column is not a column of the dataframe
#
#   FitFailedWarning)
# nan

# %%
# column_tranf
# Out:
# ColumnTransformer(n_jobs=None, remainder='passthrough', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(categories='auto', drop=None,
#                                                dtype=<class 'numpy.float64'>,
#                                                handle_unknown='error',
#                                                sparse=True),
#                                  ['Superhost', 'Borough', 'Room_type',
#                                   'bed_type'])],
#                   verbose=False)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 23)
# tree = DecisionTreeClassifier()
# tree.fit(x_train, y_train)
# train_preds = tree.predict(x_train)
# test_preds = tree.predict(x_test)

# %%
# Using Decision Tree Model
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)
clf.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-5751bf6a02a1> in <module>
#       2 from sklearn import tree
#       3 clf = tree.DecisionTreeClassifier()
# ----> 4 clf = clf.fit(x_train, y_train)
#       5 clf.score(x_test, y_test)
#
# c:\users\cheikh_moctar\documents\ucf_bootcamp\ripos_git\class_repo\env\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# c:\users\cheikh_moctar\documents\ucf_bootcamp\ripos_git\class_repo\env\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     147
#     148         if check_input:
# --> 149             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     150             y = check_array(y, ensure_2d=False, dtype=None)
#     151             if issparse(X):
#
# c:\users\cheikh_moctar\documents\ucf_bootcamp\ripos_git\class_repo\env\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# c:\users\cheikh_moctar\documents\ucf_bootcamp\ripos_git\class_repo\env\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'No'
