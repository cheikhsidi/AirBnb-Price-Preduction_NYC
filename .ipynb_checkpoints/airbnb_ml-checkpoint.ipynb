# %%
# from azureml.core import Workspace
import pandas as pd
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy.orm import sessionmaker
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import os

# %% [markdown]
# Loading Data

# %%
connectstr = f'postgresql://cheikh:prayer5subhanallah@mypostgres.cj63yqlprydj.us-east-2.rds.amazonaws.com:5432/Airbnb_NYC'
engine = create_engine(connectstr)
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
# create a configured "Session" class
Session = sessionmaker(bind=engine)

# create a Session
session = Session()
data = Base.classes.airbnb_nyc
neib_list = session.query(data).statement
df1 = pd.read_sql_query(neib_list, session.bind)

# %%
df1.head()
# Out:
#        id  host_id host_since  host_response_time host_response_rate  \
# 0  918239  4930847   2/1/2013  a few days or more                20%
# 1  918426  4932354   2/1/2013      within an hour               100%
# 2  919491  4938247   2/2/2013        within a day               100%
# 3  919830  1895793  3/10/2012      within an hour               100%
# 4  919955   794794   7/8/2011        within a day                67%
#
#   host_acceptance_rate Superhost host_neighbourhood host_listings_count  \
# 0                    0        No       Williamsburg                   1
# 1                    0       Yes   Prospect Heights                   4
# 2                    0        No         Park Slope                   1
# 3                    0       Yes            Chelsea                   1
# 4                    0        No    Upper East Side                   1
#
#   host_total_listings_count  ... minimum_nights maximum_nights  \
# 0                         1  ...              1             90
# 1                         4  ...              3             14
# 2                         1  ...              2            180
# 3                         1  ...              2              7
# 4                         1  ...             14           1124
#
#   availability_365 calendar_last_scraped number_of_reviews Review_Rating  \
# 0               64             12/6/2019               114            95
# 1              134             12/6/2019                80            93
# 2                0             12/5/2019               175            93
# 3              167             12/6/2019               176            96
# 4              354             12/6/2019                11            96
#
#   review_scores_cleanliness  review_scores_value  instant_bookable  \
# 0                         9                   10                 f
# 1                         9                   10                 f
# 2                         9                    9                 f
# 3                        10                   10                 t
# 4                         9                    9                 f
#
#   Review Rating
# 0  4th Quartile
# 1  4th Quartile
# 2  4th Quartile
# 3  4th Quartile
# 4  4th Quartile
#
# [5 rows x 44 columns]

# %%
df = df1.drop(['id','neighbourhood', 'Review Rating','host_since', 'host_response_time','amenities','street', 'host_verifications','calendar_last_scraped','host_identity_verified',  'host_has_profile_pic', 'neighbourhood_cleansed',  'instant_bookable','host_acceptance_rate', 'host_id', 'host_listings_count', 'host_total_listings_count', 'minimum_nights', 'maximum_nights'], axis = 1)

# %%
df.isnull().sum()
# Out:
# host_response_rate           0
# Superhost                    0
# host_neighbourhood           0
# Borough                      0
# latitude                     0
# longitude                    0
# property_type                0
# Room_Type                    0
# accommodates                 0
# bathrooms                    0
# bedrooms                     0
# beds                         0
# bed_type                     0
# Price                        0
# weekly_price                 0
# monthly_price                0
# security_deposit             0
# cleaning_fee                 0
# guests_included              0
# extra_people                 0
# availability_365             0
# number_of_reviews            0
# Review_Rating                0
# review_scores_cleanliness    0
# review_scores_value          0
# dtype: int64

# %%
df.head().T
# Out:
#                                       0                 1             2  \
# host_response_rate                  20%              100%          100%
# Superhost                            No               Yes            No
# host_neighbourhood         Williamsburg  Prospect Heights    Park Slope
# Borough                        Brooklyn          Brooklyn      Brooklyn
# latitude                        40.7016           40.6785       40.6767
# longitude                      -73.9435          -73.9701      -73.9792
# property_type                      Loft         Townhouse     Apartment
# Room_Type                  Private room      Private room  Private room
# accommodates                          1                 2             4
# bathrooms                             1                 1             1
# bedrooms                              1                 1             1
# beds                                  0                 1             2
# bed_type                       Real Bed          Real Bed      Real Bed
# Price                                60                70            70
# weekly_price                   $500.00           $450.00       $600.00
# monthly_price                $1,800.00                  0    $2,000.00
# security_deposit                      0               200             0
# cleaning_fee                         25                20            30
# guests_included                       1                 1             2
# extra_people                    $20.00            $10.00        $30.00
# availability_365                     64               134             0
# number_of_reviews                   114                80           175
# Review_Rating                        95                93            93
# review_scores_cleanliness             9                 9             9
# review_scores_value                  10                10             9
#
#                                       3                4
# host_response_rate                 100%              67%
# Superhost                           Yes               No
# host_neighbourhood              Chelsea  Upper East Side
# Borough                       Manhattan        Manhattan
# latitude                         40.746           40.764
# longitude                      -73.9991         -73.9639
# property_type                 Apartment        Apartment
# Room_Type                  Private room  Entire home/apt
# accommodates                          2                3
# bathrooms                             1                1
# bedrooms                              1                1
# beds                                  1                1
# bed_type                       Real Bed         Real Bed
# Price                               125              220
# weekly_price                          0       $1,950.00
# monthly_price                         0       $6,300.00
# security_deposit                      0             1000
# cleaning_fee                          0              125
# guests_included                       1                2
# extra_people                    $50.00           $50.00
# availability_365                    167              354
# number_of_reviews                   176               11
# Review_Rating                        96               96
# review_scores_cleanliness            10                9
# review_scores_value                  10                9

# %%
df['host_response_rate'] = df['host_response_rate'].str.replace('%', '').astype(int)
df['extra_people'] = df['extra_people'].str.replace('$', '').str.replace(',', '').str.strip().astype(float)
df['weekly_price'] = df['weekly_price'].str.replace('$', '').str.replace(',', '').str.strip().astype(float)
df['monthly_price'] = df['monthly_price'].str.replace('$', '').str.replace(',', '').str.strip().astype(float)

# %%
df['bathrooms'] = df['bathrooms'].astype(float)
df['bedrooms'] = df['bedrooms'].astype(float)

# %%
df.head().T
# Out:
#                                       0                 1             2  \
# host_response_rate                   20               100           100
# Superhost                            No               Yes            No
# host_neighbourhood         Williamsburg  Prospect Heights    Park Slope
# Borough                        Brooklyn          Brooklyn      Brooklyn
# latitude                        40.7016           40.6785       40.6767
# longitude                      -73.9435          -73.9701      -73.9792
# property_type                      Loft         Townhouse     Apartment
# Room_Type                  Private room      Private room  Private room
# accommodates                          1                 2             4
# bathrooms                             1                 1             1
# bedrooms                              1                 1             1
# beds                                  0                 1             2
# bed_type                       Real Bed          Real Bed      Real Bed
# Price                                60                70            70
# weekly_price                        500               450           600
# monthly_price                      1800                 0          2000
# security_deposit                      0               200             0
# cleaning_fee                         25                20            30
# guests_included                       1                 1             2
# extra_people                         20                10            30
# availability_365                     64               134             0
# number_of_reviews                   114                80           175
# Review_Rating                        95                93            93
# review_scores_cleanliness             9                 9             9
# review_scores_value                  10                10             9
#
#                                       3                4
# host_response_rate                  100               67
# Superhost                           Yes               No
# host_neighbourhood              Chelsea  Upper East Side
# Borough                       Manhattan        Manhattan
# latitude                         40.746           40.764
# longitude                      -73.9991         -73.9639
# property_type                 Apartment        Apartment
# Room_Type                  Private room  Entire home/apt
# accommodates                          2                3
# bathrooms                             1                1
# bedrooms                              1                1
# beds                                  1                1
# bed_type                       Real Bed         Real Bed
# Price                               125              220
# weekly_price                          0             1950
# monthly_price                         0             6300
# security_deposit                      0             1000
# cleaning_fee                          0              125
# guests_included                       1                2
# extra_people                         50               50
# availability_365                    167              354
# number_of_reviews                   176               11
# Review_Rating                        96               96
# review_scores_cleanliness            10                9
# review_scores_value                  10                9

# %% [markdown]
# Data Exploration

# %%
plt.figure(figsize=(20,6))
sb.distplot(df['Price'], rug=True)

# %%
df.dtypes
# Out:
# host_response_rate             int32
# Superhost                     object
# host_neighbourhood            object
# Borough                       object
# latitude                     float64
# longitude                    float64
# property_type                 object
# Room_Type                     object
# accommodates                   int64
# bathrooms                    float64
# bedrooms                     float64
# beds                          object
# bed_type                      object
# Price                        float64
# weekly_price                 float64
# monthly_price                float64
# security_deposit              object
# cleaning_fee                  object
# guests_included                int64
# extra_people                 float64
# availability_365               int64
# number_of_reviews              int64
# Review_Rating                  int64
# review_scores_cleanliness     object
# review_scores_value           object
# dtype: object

# %%
plt.figure(figsize=(20,6))
plt.scatter(df['host_neighbourhood'], df['Price'])

# %%
corr = df.corr()
corr
# Out:
#                     host_response_rate  latitude  longitude  accommodates  \
# host_response_rate            1.000000 -0.014452   0.103830      0.146204
# latitude                     -0.014452  1.000000   0.077338     -0.040072
# longitude                     0.103830  0.077338   1.000000     -0.004247
# accommodates                  0.146204 -0.040072  -0.004247      1.000000
# bathrooms                     0.066298 -0.065559   0.007219      0.342187
# bedrooms                      0.083194 -0.071660   0.035591      0.655265
# Price                         0.015324  0.029713  -0.112691      0.228735
# weekly_price                 -0.056280 -0.004991  -0.074302      0.084746
# monthly_price                 0.009811  0.008745  -0.061649      0.082785
# guests_included               0.152851 -0.055792   0.040270      0.572374
# extra_people                  0.129396 -0.000764   0.020297      0.113019
# availability_365              0.454461 -0.005718   0.083672      0.141540
# number_of_reviews             0.288381 -0.016413   0.058904      0.071523
# Review_Rating                 0.225100 -0.037096   0.044766      0.052298
#
#                     bathrooms  bedrooms     Price  weekly_price  \
# host_response_rate   0.066298  0.083194  0.015324     -0.056280
# latitude            -0.065559 -0.071660  0.029713     -0.004991
# longitude            0.007219  0.035591 -0.112691     -0.074302
# accommodates         0.342187  0.655265  0.228735      0.084746
# bathrooms            1.000000  0.421680  0.150060      0.083241
# bedrooms             0.421680  1.000000  0.173747      0.093959
# Price                0.150060  0.173747  1.000000      0.057500
# weekly_price         0.083241  0.093959  0.057500      1.000000
# monthly_price        0.053495  0.074334  0.050563      0.586222
# guests_included      0.203526  0.437289  0.108896      0.079501
# extra_people         0.048334  0.097612  0.027434      0.079634
# availability_365     0.099289  0.078932  0.064602     -0.005203
# number_of_reviews   -0.032370  0.019217 -0.041875      0.094124
# Review_Rating       -0.043208  0.009709 -0.074242      0.049271
#
#                     monthly_price  guests_included  extra_people  \
# host_response_rate       0.009811         0.152851      0.129396
# latitude                 0.008745        -0.055792     -0.000764
# longitude               -0.061649         0.040270      0.020297
# accommodates             0.082785         0.572374      0.113019
# bathrooms                0.053495         0.203526      0.048334
# bedrooms                 0.074334         0.437289      0.097612
# Price                    0.050563         0.108896      0.027434
# weekly_price             0.586222         0.079501      0.079634
# monthly_price            1.000000         0.079029      0.078862
# guests_included          0.079029         1.000000      0.321317
# extra_people             0.078862         0.321317      1.000000
# availability_365         0.061879         0.112676      0.086924
# number_of_reviews        0.121737         0.119822      0.119081
# Review_Rating            0.066541         0.115139      0.139069
#
#                     availability_365  number_of_reviews  Review_Rating
# host_response_rate          0.454461           0.288381       0.225100
# latitude                   -0.005718          -0.016413      -0.037096
# longitude                   0.083672           0.058904       0.044766
# accommodates                0.141540           0.071523       0.052298
# bathrooms                   0.099289          -0.032370      -0.043208
# bedrooms                    0.078932           0.019217       0.009709
# Price                       0.064602          -0.041875      -0.074242
# weekly_price               -0.005203           0.094124       0.049271
# monthly_price               0.061879           0.121737       0.066541
# guests_included             0.112676           0.119822       0.115139
# extra_people                0.086924           0.119081       0.139069
# availability_365            1.000000           0.118058       0.018199
# number_of_reviews           0.118058           1.000000       0.279848
# Review_Rating               0.018199           0.279848       1.000000

# %%
# %matplotlib inline
plt.figure(figsize=(15, 15))
sb.heatmap(corr, annot=True)

# %%
import geopy.distance
cols =['latitude', 'longitude']
df['location'] = df[cols].apply(lambda row: ', '.join(row.values.astype(str)), axis=1)

df['location'] =  df['location'].apply(lambda row: tuple(map(float, row.split(', '))))
df['location']
coords = (40.758896, -73.985130)
df['distance'] =  df['location'].apply(lambda row: geopy.distance.vincenty(coords, row).miles)
# print geopy.distance.vincenty(coords_1, coords_2).km
# Out:
# c:\users\cheikh_moctar\documents\ucf_bootcamp\ripos_git\class_repo\env\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.

# %%
df['location']
# Out:
# 0        (40.70159, -73.94346)
# 1        (40.67852, -73.97008)
# 2        (40.67665, -73.97925)
# 3        (40.74605, -73.99906)
# 4        (40.76403, -73.96386)
#                  ...
# 50594    (40.66414, -73.98457)
# 50595    (40.72361, -73.97877)
# 50596    (40.73356, -73.99876)
# 50597    (40.73949, -73.99483)
# 50598    (40.68336, -73.93648)
# Name: location, Length: 50599, dtype: object

# %%
# Out:
# Collecting geopy
#   Downloading geopy-1.21.0-py2.py3-none-any.whl (104 kB)
# Collecting geographiclib<2,>=1.49
#   Using cached geographiclib-1.50-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-1.21.0
# Note: you may need to restart the kernel to use updated packages.
