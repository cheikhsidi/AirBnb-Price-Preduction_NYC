# %%
# from azureml.core import Workspace
import pandas as pd
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy.orm import sessionmaker
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import os
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Loading Data

# %%
# Loading the Dataset
df1 = pd.read_csv('airbnb_nyc.csv')
df1.head()
# Out:
#    Unnamed: 0      id  host_id host_since  host_response_time  \
# 0           0  918239  4930847   2/1/2013  a few days or more
# 1           1  918426  4932354   2/1/2013      within an hour
# 2           2  919491  4938247   2/2/2013        within a day
# 3           3  919830  1895793  3/10/2012      within an hour
# 4           4  919955   794794   7/8/2011        within a day
#
#   host_response_rate  host_acceptance_rate Superhost host_neighbourhood  \
# 0                20%                     0        No       Williamsburg
# 1               100%                     0       Yes   Prospect Heights
# 2               100%                     0        No         Park Slope
# 3               100%                     0       Yes            Chelsea
# 4                67%                     0        No    Upper East Side
#
#    host_listings_count  ...  minimum_nights maximum_nights availability_365  \
# 0                    1  ...               1             90               64
# 1                    4  ...               3             14              134
# 2                    1  ...               2            180                0
# 3                    1  ...               2              7              167
# 4                    1  ...              14           1124              354
#
#   calendar_last_scraped number_of_reviews Review_Rating  \
# 0             12/6/2019               114            95
# 1             12/6/2019                80            93
# 2             12/5/2019               175            93
# 3             12/6/2019               176            96
# 4             12/6/2019                11            96
#
#   review_scores_cleanliness review_scores_value  instant_bookable  \
# 0                         9                  10                 f
# 1                         9                  10                 f
# 2                         9                   9                 f
# 3                        10                  10                 t
# 4                         9                   9                 f
#
#    Review Rating
# 0   4th Quartile
# 1   4th Quartile
# 2   4th Quartile
# 3   4th Quartile
# 4   4th Quartile
#
# [5 rows x 45 columns]

# %% [markdown]
# # Data Exploration

# %%
df1.host_neighbourhood.nunique()
# Out:
# 432

# %%
# Dumping all irrelevant columns
df = df1.drop(['id','neighbourhood', 'Review Rating','host_since', 'host_response_time','amenities',
               'street', 'host_verifications','calendar_last_scraped','host_identity_verified',  'host_has_profile_pic', 
               'neighbourhood_cleansed',  'instant_bookable','host_acceptance_rate', 'host_id', 'host_listings_count', 
               'host_total_listings_count', 'minimum_nights', 'maximum_nights', 'property_type', 'Unnamed: 0'], axis = 1)

# %%
# Checking for nulls 
df.isnull().sum()
# Out:
# host_response_rate           0
# Superhost                    0
# host_neighbourhood           0
# Borough                      0
# latitude                     0
# longitude                    0
# Room_Type                    0
# accommodates                 0
# bathrooms                    0
# bedrooms                     0
# beds                         0
# bed_type                     0
# Price                        0
# weekly_price                 0
# monthly_price                0
# security_deposit             0
# cleaning_fee                 0
# guests_included              0
# extra_people                 0
# availability_365             0
# number_of_reviews            0
# Review_Rating                0
# review_scores_cleanliness    0
# review_scores_value          0
# dtype: int64

# %%
# inspeting the all the columns datatypes
df.head().T
# Out:
#                                       0                 1             2  \
# host_response_rate                  20%              100%          100%
# Superhost                            No               Yes            No
# host_neighbourhood         Williamsburg  Prospect Heights    Park Slope
# Borough                        Brooklyn          Brooklyn      Brooklyn
# latitude                        40.7016           40.6785       40.6767
# longitude                      -73.9435          -73.9701      -73.9792
# Room_Type                  Private room      Private room  Private room
# accommodates                          1                 2             4
# bathrooms                             1                 1             1
# bedrooms                              1                 1             1
# beds                                  0                 1             2
# bed_type                       Real Bed          Real Bed      Real Bed
# Price                                60                70            70
# weekly_price                   $500.00           $450.00       $600.00
# monthly_price                $1,800.00                  0    $2,000.00
# security_deposit                      0               200             0
# cleaning_fee                         25                20            30
# guests_included                       1                 1             2
# extra_people                    $20.00            $10.00        $30.00
# availability_365                     64               134             0
# number_of_reviews                   114                80           175
# Review_Rating                        95                93            93
# review_scores_cleanliness             9                 9             9
# review_scores_value                  10                10             9
#
#                                       3                4
# host_response_rate                 100%              67%
# Superhost                           Yes               No
# host_neighbourhood              Chelsea  Upper East Side
# Borough                       Manhattan        Manhattan
# latitude                         40.746           40.764
# longitude                      -73.9991         -73.9639
# Room_Type                  Private room  Entire home/apt
# accommodates                          2                3
# bathrooms                             1                1
# bedrooms                              1                1
# beds                                  1                1
# bed_type                       Real Bed         Real Bed
# Price                               125              220
# weekly_price                          0       $1,950.00
# monthly_price                         0       $6,300.00
# security_deposit                      0             1000
# cleaning_fee                          0              125
# guests_included                       1                2
# extra_people                    $50.00           $50.00
# availability_365                    167              354
# number_of_reviews                   176               11
# Review_Rating                        96               96
# review_scores_cleanliness            10                9
# review_scores_value                  10                9

# %%
# Transforming and casting to numerical data type
df['host_response_rate'] = df['host_response_rate'].str.replace('%', '').astype(int)
df['extra_people'] = df['extra_people'].str.replace('$', '').str.replace(',', '').str.strip().astype(float)
df['weekly_price'] = df['weekly_price'].str.replace('$', '').str.replace(',', '').str.strip().astype(float)
df['monthly_price'] = df['monthly_price'].str.replace('$', '').str.replace(',', '').str.strip().astype(float)
df['bathrooms'] = df['bathrooms'].astype(float)
df['bedrooms'] = df['bedrooms'].astype(float)

# %%
# # Creating Location column from lat-long
# cols =['latitude', 'longitude']
# df['location'] = df[cols].apply(lambda row: ', '.join(row.values.astype(str)), axis=1)
# df['location'] =  df['location'].apply(lambda row: tuple(map(float, row.split(', '))))

# %%
# checking visually the columns data type
df.head().T
# Out:
#                                       0                 1             2  \
# host_response_rate                   20               100           100
# Superhost                            No               Yes            No
# host_neighbourhood         Williamsburg  Prospect Heights    Park Slope
# Borough                        Brooklyn          Brooklyn      Brooklyn
# latitude                        40.7016           40.6785       40.6767
# longitude                      -73.9435          -73.9701      -73.9792
# Room_Type                  Private room      Private room  Private room
# accommodates                          1                 2             4
# bathrooms                             1                 1             1
# bedrooms                              1                 1             1
# beds                                  0                 1             2
# bed_type                       Real Bed          Real Bed      Real Bed
# Price                                60                70            70
# weekly_price                        500               450           600
# monthly_price                      1800                 0          2000
# security_deposit                      0               200             0
# cleaning_fee                         25                20            30
# guests_included                       1                 1             2
# extra_people                         20                10            30
# availability_365                     64               134             0
# number_of_reviews                   114                80           175
# Review_Rating                        95                93            93
# review_scores_cleanliness             9                 9             9
# review_scores_value                  10                10             9
#
#                                       3                4
# host_response_rate                  100               67
# Superhost                           Yes               No
# host_neighbourhood              Chelsea  Upper East Side
# Borough                       Manhattan        Manhattan
# latitude                         40.746           40.764
# longitude                      -73.9991         -73.9639
# Room_Type                  Private room  Entire home/apt
# accommodates                          2                3
# bathrooms                             1                1
# bedrooms                              1                1
# beds                                  1                1
# bed_type                       Real Bed         Real Bed
# Price                               125              220
# weekly_price                          0             1950
# monthly_price                         0             6300
# security_deposit                      0             1000
# cleaning_fee                          0              125
# guests_included                       1                2
# extra_people                         50               50
# availability_365                    167              354
# number_of_reviews                   176               11
# Review_Rating                        96               96
# review_scores_cleanliness            10                9
# review_scores_value                  10                9

# %% [markdown]
# Data Exploration

# %%
# checking the columns data type
df.dtypes
# Out:
# host_response_rate             int32
# Superhost                     object
# host_neighbourhood            object
# Borough                       object
# latitude                     float64
# longitude                    float64
# Room_Type                     object
# accommodates                   int64
# bathrooms                    float64
# bedrooms                     float64
# beds                           int64
# bed_type                      object
# Price                        float64
# weekly_price                 float64
# monthly_price                float64
# security_deposit               int64
# cleaning_fee                   int64
# guests_included                int64
# extra_people                 float64
# availability_365               int64
# number_of_reviews              int64
# Review_Rating                  int64
# review_scores_cleanliness      int64
# review_scores_value            int64
# dtype: object

# %%
# Removinf price outliers
df = df[df['Price'] <300]
len(df)
# Out:
# 46610

# %%
# Plotting the distribution of the price
ax = sb.distplot(df['Price'], axlabel='Listing Price')

# %%
# Price Box plot per Borough
boxprops = dict(linestyle='-', linewidth=4, color='k')
medianprops = dict(linestyle='-', linewidth=4, color='k')

df.boxplot(column='Price', by='Borough', boxprops=boxprops,
                medianprops=medianprops, figsize=(20,6))

# setting title
plt.suptitle("Price by Borough")
# Out:
# Text(0.5, 0.98, 'Price by Borough')

# %%
#  Plotting the distribution of price spatially
df.plot.scatter(x='longitude', y = 'latitude', c='Price', figsize=(20,20), cmap='cool', alpha=0.5 )

# %%
# Calculating the Distance from Time Square 
import geopy.distance

cols =['latitude', 'longitude']
df['location'] = df[cols].apply(lambda row: ', '.join(row.values.astype(str)), axis=1)
df['location'] =  df['location'].apply(lambda row: tuple(map(float, row.split(', '))))

# Time Square Location
coords = (40.758896, -73.985130)
df['distance'] =  df['location'].apply(lambda row: geopy.distance.vincenty(coords, row).miles)
# print geopy.distance.vincenty(coords_1, coords_2).km
df['distance']
# Out:
# 0        4.518910
# 1        5.602132
# 2        5.683554
# 3        1.148927
# 4        1.170857
#            ...
# 50594    6.538442
# 50595    2.457599
# 50596    1.888921
# 50597    1.432552
# 50598    5.804301
# Name: distance, Length: 46610, dtype: float64

# %%
# Creating coorelation between all features
corr = df.corr()
corr
# Out:
#                            host_response_rate  latitude  longitude  \
# host_response_rate                   1.000000 -0.018760   0.114207
# latitude                            -0.018760  1.000000   0.086092
# longitude                            0.114207  0.086092   1.000000
# accommodates                         0.138057 -0.053971   0.032819
# bathrooms                            0.059633 -0.078936   0.047528
# bedrooms                             0.065948 -0.085224   0.082751
# beds                                 0.124614 -0.062432   0.046306
# Price                                0.038314  0.070462  -0.302731
# weekly_price                        -0.061362 -0.003372  -0.078124
# monthly_price                        0.015191  0.011609  -0.067350
# security_deposit                     0.057653  0.019685  -0.080260
# cleaning_fee                         0.215200  0.019853  -0.163337
# guests_included                      0.147843 -0.066232   0.059463
# extra_people                         0.129872 -0.000737   0.028135
# availability_365                     0.458744 -0.012162   0.097166
# number_of_reviews                    0.295358 -0.012705   0.052299
# Review_Rating                        0.224282 -0.029733   0.032642
# review_scores_cleanliness            0.239961 -0.029918   0.040895
# review_scores_value                  0.220803 -0.032169   0.038587
# distance                             0.104191 -0.412091   0.542589
#
#                            accommodates  bathrooms  bedrooms      beds  \
# host_response_rate             0.138057   0.059633  0.065948  0.124614
# latitude                      -0.053971  -0.078936 -0.085224 -0.062432
# longitude                      0.032819   0.047528  0.082751  0.046306
# accommodates                   1.000000   0.144685  0.562617  0.712081
# bathrooms                      0.144685   1.000000  0.221165  0.186982
# bedrooms                       0.562617   0.221165  1.000000  0.555902
# beds                           0.712081   0.186982  0.555902  1.000000
# Price                          0.471891  -0.009529  0.227009  0.303221
# weekly_price                   0.060748   0.000071  0.055295  0.049420
# monthly_price                  0.064362  -0.010726  0.046481  0.050740
# security_deposit               0.116079   0.003372  0.060825  0.082846
# cleaning_fee                   0.360762   0.036448  0.200963  0.265699
# guests_included                0.545974   0.078075  0.364198  0.443992
# extra_people                   0.093041   0.014322  0.071003  0.089939
# availability_365               0.119466   0.093321  0.053195  0.128835
# number_of_reviews              0.106381  -0.019791  0.037889  0.082761
# Review_Rating                  0.078327  -0.035353  0.019635  0.057419
# review_scores_cleanliness      0.086256  -0.038059  0.022294  0.063239
# review_scores_value            0.075931  -0.032907  0.021597  0.056361
# distance                       0.073022   0.073632  0.141748  0.103005
#
#                               Price  weekly_price  monthly_price  \
# host_response_rate         0.038314     -0.061362       0.015191
# latitude                   0.070462     -0.003372       0.011609
# longitude                 -0.302731     -0.078124      -0.067350
# accommodates               0.471891      0.060748       0.064362
# bathrooms                 -0.009529      0.000071      -0.010726
# bedrooms                   0.227009      0.055295       0.046481
# beds                       0.303221      0.049420       0.050740
# Price                      1.000000      0.137855       0.116567
# weekly_price               0.137855      1.000000       0.612369
# monthly_price              0.116567      0.612369       1.000000
# security_deposit           0.186526      0.089622       0.149676
# cleaning_fee               0.456689      0.086033       0.137440
# guests_included            0.287591      0.076475       0.069800
# extra_people               0.057103      0.067013       0.066923
# availability_365           0.052871      0.000913       0.082407
# number_of_reviews         -0.020866      0.121614       0.148164
# Review_Rating             -0.010716      0.068562       0.080956
# review_scores_cleanliness -0.003029      0.065116       0.080374
# review_scores_value       -0.025784      0.065221       0.075012
# distance                  -0.366602     -0.058092      -0.067020
#
#                            security_deposit  cleaning_fee  guests_included  \
# host_response_rate                 0.057653      0.215200         0.147843
# latitude                           0.019685      0.019853        -0.066232
# longitude                         -0.080260     -0.163337         0.059463
# accommodates                       0.116079      0.360762         0.545974
# bathrooms                          0.003372      0.036448         0.078075
# bedrooms                           0.060825      0.200963         0.364198
# beds                               0.082846      0.265699         0.443992
# Price                              0.186526      0.456689         0.287591
# weekly_price                       0.089622      0.086033         0.076475
# monthly_price                      0.149676      0.137440         0.069800
# security_deposit                   1.000000      0.353558         0.097958
# cleaning_fee                       0.353558      1.000000         0.274590
# guests_included                    0.097958      0.274590         1.000000
# extra_people                       0.111689      0.146864         0.295633
# availability_365                   0.096473      0.196790         0.100376
# number_of_reviews                 -0.017784      0.006879         0.141349
# Review_Rating                      0.004848      0.057326         0.118862
# review_scores_cleanliness          0.010175      0.065674         0.126498
# review_scores_value               -0.002901      0.044748         0.117782
# distance                          -0.085340     -0.171515         0.100956
#
#                            extra_people  availability_365  number_of_reviews  \
# host_response_rate             0.129872          0.458744           0.295358
# latitude                      -0.000737         -0.012162          -0.012705
# longitude                      0.028135          0.097166           0.052299
# accommodates                   0.093041          0.119466           0.106381
# bathrooms                      0.014322          0.093321          -0.019791
# bedrooms                       0.071003          0.053195           0.037889
# beds                           0.089939          0.128835           0.082761
# Price                          0.057103          0.052871          -0.020866
# weekly_price                   0.067013          0.000913           0.121614
# monthly_price                  0.066923          0.082407           0.148164
# security_deposit               0.111689          0.096473          -0.017784
# cleaning_fee                   0.146864          0.196790           0.006879
# guests_included                0.295633          0.100376           0.141349
# extra_people                   1.000000          0.087109           0.124607
# availability_365               0.087109          1.000000           0.127166
# number_of_reviews              0.124607          0.127166           1.000000
# Review_Rating                  0.137884          0.023589           0.274127
# review_scores_cleanliness      0.143000          0.039436           0.283396
# review_scores_value            0.134995          0.017332           0.277212
# distance                       0.024407          0.097693           0.052655
#
#                            Review_Rating  review_scores_cleanliness  \
# host_response_rate              0.224282                   0.239961
# latitude                       -0.029733                  -0.029918
# longitude                       0.032642                   0.040895
# accommodates                    0.078327                   0.086256
# bathrooms                      -0.035353                  -0.038059
# bedrooms                        0.019635                   0.022294
# beds                            0.057419                   0.063239
# Price                          -0.010716                  -0.003029
# weekly_price                    0.068562                   0.065116
# monthly_price                   0.080956                   0.080374
# security_deposit                0.004848                   0.010175
# cleaning_fee                    0.057326                   0.065674
# guests_included                 0.118862                   0.126498
# extra_people                    0.137884                   0.143000
# availability_365                0.023589                   0.039436
# number_of_reviews               0.274127                   0.283396
# Review_Rating                   1.000000                   0.983591
# review_scores_cleanliness       0.983591                   1.000000
# review_scores_value             0.987060                   0.977105
# distance                        0.057331                   0.066369
#
#                            review_scores_value  distance
# host_response_rate                    0.220803  0.104191
# latitude                             -0.032169 -0.412091
# longitude                             0.038587  0.542589
# accommodates                          0.075931  0.073022
# bathrooms                            -0.032907  0.073632
# bedrooms                              0.021597  0.141748
# beds                                  0.056361  0.103005
# Price                                -0.025784 -0.366602
# weekly_price                          0.065221 -0.058092
# monthly_price                         0.075012 -0.067020
# security_deposit                     -0.002901 -0.085340
# cleaning_fee                          0.044748 -0.171515
# guests_included                       0.117782  0.100956
# extra_people                          0.134995  0.024407
# availability_365                      0.017332  0.097693
# number_of_reviews                     0.277212  0.052655
# Review_Rating                         0.987060  0.057331
# review_scores_cleanliness             0.977105  0.066369
# review_scores_value                   1.000000  0.066980
# distance                              0.066980  1.000000

# %%
plt.figure(figsize=(15, 15))
corr = df.corr()
sb.heatmap(corr, annot=True, cmap = 'viridis_r')
plt.title('Correlation HeatMap')
# Out:
# Text(0.5, 1, 'Correlation HeatMap')

# %%
# Price vs Distance from Time Square

plt.figure(figsize=(15, 5))
sb.regplot(data = df, x = "distance", y = 'Price', x_jitter = 0.1, 
            scatter_kws = {'alpha': 0.1})
plt.title('Price vs distance from Time Square')
# Out:
# Text(0.5, 1.0, 'Price vs distance from Time Square')

# %% [markdown]
# # Borough Exploratory and Analysis

# %%
Manhattan = df[df['Borough'] == 'Manhattan']
Brooklyn= df[df['Borough'] == 'Brooklyn']
Bronx = df[df['Borough'] == 'Bronx']
Queens = df[df['Borough'] == 'Queens']
StatenIsland = df[df['Borough'] == 'Staten Island']

# %%
Queens
# Out:
#        host_response_rate Superhost host_neighbourhood Borough  latitude  \
# 16                    100        No            Jamaica  Queens  40.70715
# 24                      0        No           Flushing  Queens  40.75444
# 49                    100       Yes          Ridgewood  Queens  40.70990
# 59                    100        No    Jackson Heights  Queens  40.76356
# 73                    100        No            Astoria  Queens  40.75751
# ...                   ...       ...                ...     ...       ...
# 50496                  70        No           Flushing  Queens  40.76014
# 50516                   0        No            Astoria  Queens  40.76488
# 50564                 100       Yes           Flushing  Queens  40.75088
# 50565                 100       Yes           Flushing  Queens  40.75250
# 50570                   0        No    Jackson Heights  Queens  40.75374
#
#        longitude        Room_Type  accommodates  bathrooms  bedrooms  ...  \
# 16     -73.81468  Entire home/apt             2        1.0       1.0  ...
# 24     -73.83057     Private room             2        1.0       1.0  ...
# 49     -73.91509  Entire home/apt             2        1.0       1.0  ...
# 59     -73.88850  Entire home/apt             4        1.0       1.0  ...
# 73     -73.91678  Entire home/apt             2        1.0       1.0  ...
# ...          ...              ...           ...        ...       ...  ...
# 50496  -73.81146     Private room             2        1.0       1.0  ...
# 50516  -73.92970  Entire home/apt             2        1.0       1.0  ...
# 50564  -73.81029     Private room             1        1.5       1.0  ...
# 50565  -73.81126  Entire home/apt             3        1.0       0.0  ...
# 50570  -73.89240     Private room             2        1.0       1.0  ...
#
#        cleaning_fee guests_included  extra_people  availability_365  \
# 16               54               1          15.0               207
# 24               13               1          15.0                 0
# 49               25               2         100.0               311
# 59               55               2          15.0                 1
# 73               60               1          10.0               318
# ...             ...             ...           ...               ...
# 50496            10               1          20.0               353
# 50516           100               2          25.0               126
# 50564             0               1           0.0                 0
# 50565             0               2          10.0               312
# 50570            20               1           0.0                91
#
#        number_of_reviews  Review_Rating  review_scores_cleanliness  \
# 16                    88             93                          9
# 24                    75             94                         10
# 49                    80             95                         10
# 59                   165             90                          9
# 73                   292             88                          9
# ...                  ...            ...                        ...
# 50496                 43             92                          9
# 50516                  0              0                          0
# 50564                128             97                         10
# 50565                337             94                          9
# 50570                  0              0                          0
#
#        review_scores_value                         location  distance
# 16                       9   (40.70715, -73.81468000000001)  9.633027
# 24                       9            (40.75444, -73.83057)  8.115739
# 49                      10             (40.7099, -73.91509)  4.994522
# 59                       9             (40.76356, -73.8885)  5.080128
# 73                       9  (40.757509999999996, -73.91678)  3.587583
# ...                    ...                              ...       ...
# 50496                    9            (40.76014, -73.81146)  9.112648
# 50516                    0             (40.76488, -73.9297)  2.937405
# 50564                   10   (40.75088, -73.81029000000001)  9.190927
# 50565                   10             (40.7525, -73.81126)  9.133928
# 50570                    0             (40.75374, -73.8924)  4.878649
#
# [6058 rows x 26 columns]

# %%
# Plotting the distribution of the price in the 5 boroughs
def plot_histBorough(a):
    x1 = Manhattan[a]
    x2 = Brooklyn[a]
    x3 = Queens[a]
    x4 = Bronx[a]
    x5 = StatenIsland[a]
    
    fig, axs = plt.subplots(3, 2, figsize=(20,10))   
    axs[0, 0].hist(x1, color = 'r', bins=50)
    axs[0, 0].set_title(f'Manhattan {a}')
    axs[0, 1].hist(x2, color = 'g', bins=50)
    axs[0, 1].set_title(f'Brooklyn {a}')
    axs[1, 0].hist(x3, color='b', bins=50)
    axs[1, 0].set_title(f'Queens {a}')
    axs[1, 1].hist(x4, color = 'k',  bins=50)
    axs[1, 1].set_title(f'Bronx {a}')
    axs[2, 0].hist(x5, color = 'y',  bins=50)
    axs[2, 0].set_title(f'Staten Island {a}')
    return plt.show

# %%
plot_histBorough('Price')
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Plotting scatter plot between the price and the distace from Time Square in the 5 borough
def plot_borough(a, b):
    x1 = Manhattan[a]
    y1 = Manhattan[b]
    x2 = Brooklyn[a]
    y2 = Brooklyn[b]
    x3 = Queens[a]
    y3 = Queens[b]
    x4 = Bronx[a]
    y4 = Bronx[b]
    x5 = StatenIsland[a]
    y5 = StatenIsland[b]

    fig, axs = plt.subplots(3, 2, figsize=(20,10))   
    axs[0, 0].scatter(x1, y1, color = 'r', alpha = 0.2)
    z = np.polyfit(x1, y1, 1)
    p = np.poly1d(z)
    axs[0, 0].plot(x1,p(x1),"k--")
    axs[0, 0].set_title(f'Manhattan {a} vs {b}')
    axs[0, 1].scatter(x2, y2, color = 'g', alpha=0.2)
    z = np.polyfit(x2, y2, 1)
    p = np.poly1d(z)
    axs[0, 1].plot(x2,p(x2),"k--")
    axs[0, 1].set_title(f'Brooklyn {a} vs {b}')
    axs[1, 0].scatter(x3, y3, color='b', alpha=0.2)
    z = np.polyfit(x3, y3, 1)
    p = np.poly1d(z)
    axs[1, 0].plot(x3,p(x3),"k--")
    axs[1, 0].set_title(f'Queens {a} vs {b}')
    axs[1, 1].scatter(x4, y4, color = 'k',  alpha=0.2)
    z = np.polyfit(x4, y4, 1)
    p = np.poly1d(z)
    axs[1, 1].plot(x4,p(x4),"k--")
    axs[1, 1].set_title(f'Bronx {a} vs {b}')
    axs[2, 0].scatter(x5, y5, color = 'y',  alpha=0.2)
    z = np.polyfit(x5, y5, 1)
    p = np.poly1d(z)
    axs[2, 0].plot(x5,p(x5),"k--")
    axs[2, 0].set_title(f'Staten Island {a} vs {b}')
    return plt.show

# %%
plot_borough('Price', 'distance')
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Room Type Exploratory and Analysis

# %%
# Creating Dataframes for each room type
EntireHome = df[df['Room_Type']=='Entire home/apt']
PrivateRoom = df[df['Room_Type']=='Private room']
SharedRoom = df[df['Room_Type'] == 'Shared room']
HotelRoom = df[df['Room_Type'] == 'Hotel room']

# %%
# Plotting the distribution of the price in the 5 boroughs
def plot_histRoom(a):
    x1 = EntireHome[a]
    x2 = PrivateRoom[a]
    x3 = SharedRoom[a]
    x4 = HotelRoom[a]
    
    fig, axs = plt.subplots(2, 2, figsize=(20,10))   
    axs[0, 0].hist(x1, color = 'r', bins=50)
    axs[0, 0].set_title(f'Entire Home {a}')
    axs[0, 1].hist(x2, color = 'g', bins=50)
    axs[0, 1].set_title(f'Private Room {a}')
    axs[1, 0].hist(x3, color='b', bins=50)
    axs[1, 0].set_title(f'Shared Room {a}')
    axs[1, 1].hist(x4, color = 'k',  bins=50)
    axs[1, 1].set_title(f'Hotel Room {a}')

    return plt.show

# %%
plot_histRoom('Price')
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Plotting the distribution of the price in the 5 borough
def plot_Room(a, b):
    x1 = EntireRoom[a]
    y1 = EntireRoom[b]
    x2 = PrivateRoom[a]
    y2 = PrivateRoom[b]
    x3 = SharedRoom[a]
    y3 = SharedRoom[b]
    x4 = HotelRoom[a]
    y4 = HotelRoom[b]

    fig, axs = plt.subplots(2, 2, figsize=(20,10))   
    axs[0, 0].scatter(x1, y1, color = 'r', alpha = 0.2)
    z = np.polyfit(x1, y1, 1)
    p = np.poly1d(z)
    axs[0, 0].plot(x1,p(x1),"k--")
    axs[0, 0].set_title(f'EntireRoom {a} vs {b}')
    axs[0, 1].scatter(x2, y2, color = 'g', alpha=0.2)
    z = np.polyfit(x2, y2, 1)
    p = np.poly1d(z)
    axs[0, 1].plot(x2,p(x2),"k--")
    axs[0, 1].set_title(f'PrivateRoom {a} vs {b}')
    axs[1, 0].scatter(x3, y3, color='b', alpha=0.2)
    z = np.polyfit(x3, y3, 1)
    p = np.poly1d(z)
    axs[1, 0].plot(x3,p(x3),"k--")
    axs[1, 0].set_title(f'SharedRoom {a} vs {b}')
    axs[1, 1].scatter(x4, y4, color = 'k',  alpha=0.2)
    z = np.polyfit(x4, y4, 1)
    p = np.poly1d(z)
    axs[1, 1].plot(x4,p(x4),"k--")
    axs[1, 1].set_title(f'HotelRoom {a} vs {b}')

    return plt.show

# %%
plot_Room('Price', 'distance')
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Price Box plot in Manhattan per Room Type
fig, axs = plt.subplots(5, figsize=(15,30))
fig.suptitle('Vertically stacked subplots')

# axs[0].plot(x, y)
# axs[1].plot(x, -y)
boxprops = dict(linestyle='-', linewidth=4, color='k')
medianprops = dict(linestyle='-', linewidth=4, color='k')

Boroughs =['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island']
for i,el in enumerate(Boroughs):
    df[df['Borough'] == el].boxplot(column='Price', by="Room_Type", ax=axs.flatten()[i])
    plt.suptitle("")
    fig.suptitle('')
    plt.title(f"{Boroughs[i]} by Room type")

# %%
def boxplot_sorted(df, by, column):
    df2 = pd.DataFrame({col:vals[column] for col, vals in df.groupby(by)})
    meds = df2.median().sort_values(ascending=False)
    df2[meds.index].boxplot(ax=axs.flatten()[i], rot=90)

# %%
# Price Box plot in Manhattan per Room Type
fig, axs = plt.subplots(5, figsize=(60,60))
fig.suptitle('Vertically stacked subplots')

# axs[0].plot(x, y)
# axs[1].plot(x, -y)
boxprops = dict(linestyle='-', linewidth=4, color='k')
medianprops = dict(linestyle='-', linewidth=4, color='k')

Boroughs =['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island']
for i,el in enumerate(Boroughs):
    
    d = df[df['Borough'] == el]
    boxplot_sorted(d, by=["host_neighbourhood"], column="Price")
#     df[df['Borough'] == el].assign(m=df['Price'].median()).sort_values(by='m' ,ascending=0).drop('m', axis=1).boxplot(column='Price', by="host_neighbourhood", ax=axs.flatten()[i], rot= 90)
#     plt.suptitle("")
#     fig.suptitle('')
#     plt.title(f"{Boroughs[i]} by Room type")

# %% [markdown]
# # Preprocessing

# %%
# Column list by data type
g = df.columns.to_series().groupby(df.dtypes).groups
g
# Out:
# {dtype('int32'): Index(['host_response_rate'], dtype='object'),
#  dtype('int64'): Index(['accommodates', 'beds', 'security_deposit', 'cleaning_fee',
#         'guests_included', 'availability_365', 'number_of_reviews',
#         'Review_Rating', 'review_scores_cleanliness', 'review_scores_value'],
#        dtype='object'),
#  dtype('float64'): Index(['latitude', 'longitude', 'bathrooms', 'bedrooms', 'Price',
#         'weekly_price', 'monthly_price', 'extra_people', 'distance'],
#        dtype='object'),
#  dtype('O'): Index(['Superhost', 'host_neighbourhood', 'Borough', 'Room_Type', 'bed_type',
#         'location'],
#        dtype='object')}

# %%
cat_cols =['Superhost', 'host_neighbourhood', 'Borough', 'Room_Type', 'bed_type',
        'location']

# %%
# Scaling the data
# from sklearn.preprocessing import  MinMaxScaler
# X_scaler = MinMaxScaler().fit(x_train)
# X_train_scaled = X_scaler.transform(x_train)
# X_test_scaled = X_scaler.transform(x_test)

# %%
# Encoding the Categorical features
for cat in cat_cols:
    id_, name = pd.factorize(Manhattan[f'{cat}'])
    Manhattan[f'{cat}_num'] = id_

# %%
X = Manhattan.drop('Price', axis=1)
X = X.drop(cat_cols, axis=1)

y = Manhattan["Price"]
print(X.shape, y.shape)
# Out:
# (19196, 19) (19196,)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 23)

# %%
def tree_func(df):
    for cat in cat_cols:
        id_, name = pd.factorize(df[f'{cat}'])
        df[f'{cat}_num'] = id_
    
    X = df.drop('Price', axis=1)
    X = X.drop(cat_cols, axis=1)
    y = df["Price"]
    print(X.shape, y.shape)
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 23)
    rf = RandomForestRegressor(n_estimators=200, n_jobs=-1)
    rf = rf.fit(x_train, y_train)
    score = rf.score(x_test, y_test)
    preds = rf.predict(x_test)
    mse = mean_squared_error
    price_error = np.sqrt(mse(preds, y_test))
    print(f'MSE: {score}, price Error : ${price_error}')

# %%
from sklearn.ensemble import RandomForestRegressor
tree_func(Manhattan)
# Out:
# (19196, 25) (19196,)
# MSE: 0.6222911025464491, price Error : 39.63984744696288

# %%
tree_func(Bronx)
# Out:
# (1187, 25) (1187,)
# MSE: 0.40225383862850683, price Error : 35.08564808694108

# %%
tree_func(Brooklyn)
# Out:
# (19802, 25) (19802,)
# MSE: 0.647813343547484, price Error : 33.82629181895953

# %%
tree_func(Queens)
# Out:
# (6058, 25) (6058,)
# MSE: 0.5893793720422498, price Error : 31.946682593880155

# %%
tree_func(StatenIsland)
# Out:
# (367, 25) (367,)
# MSE: 0.4579818161744659, price Error : 38.467133136701996

# %%
# Using Decision Tree Model
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)
clf.score(x_test, y_test)
# Out:
# 0.07421875

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=200, n_jobs=-1)
rf = rf.fit(x_train, y_train)
rf.score(x_test, y_test)
# Out:
# 0.11770833333333333

# %%
preds = rf.predict(x_test)

# %%
# Price error 
from sklearn.metrics import mean_squared_error

mse = mean_squared_error

np.sqrt(mse(preds, y_test))
# Out:
# 52.74534191518716

# %%
feature_names = X.columns
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.12398853752969882, 'longitude'),
#  (0.12080477542801411, 'latitude'),
#  (0.12019282360038469, 'distance'),
#  (0.0785153308830514, 'number_of_reviews'),
#  (0.0745634217594769, 'availability_365'),
#  (0.07455645739594012, 'cleaning_fee'),
#  (0.057953956535666915, 'Review_Rating'),
#  (0.04812753837892021, 'security_deposit'),
#  (0.046215005343203684, 'extra_people'),
#  (0.03915456241087067, 'host_response_rate'),
#  (0.035681337979650764, 'review_scores_cleanliness'),
#  (0.031538436550960294, 'review_scores_value'),
#  (0.030931466558819957, 'accommodates'),
#  (0.025507825656854565, 'beds'),
#  (0.0219145442799123, 'bedrooms'),
#  (0.019309696913921134, 'weekly_price'),
#  (0.019047855758140962, 'guests_included'),
#  (0.01695516714854979, 'monthly_price'),
#  (0.015041259887962583, 'bathrooms')]
